# %% [markdown]
# <center>
#     <img src="https://s3.amazonaws.com/weclouddata/images/logos/wcd_logo.png" width="50%">
# </center>
#
# ----------
#
# <h1 align="center"> Introduction to Data Science with Python </h1>
# <br>
# <center align="left"> <font size='4'>  Developed by: </font><font size='4' color='#33AAFBD'>WeCloudData Academy </font></center>
# <br>
# <center align="left"> <font size='4' color='#FF5713'> Accelerating your data science career! </font></center>
# <br>
#
#
# links:
# - [`upcoming courses`](https://weclouddata.com/upcoming-courses/)
# - [`machine learning`](https://weclouddata.com/course/applied-machine-learning/)
# - [`data science`](https://weclouddata.com/course/python-for-data-science/)
# - [`immmersive bootcamp`](https://weclouddata.com/course/bootcamp/)
#
#
# ---------

# %% [markdown]
# # Schedule
#
# 1. What is Data Science
# 2. Why Python
# 3. What is Pandas?
# 4. What is a decision tree?
# 5. Hands on Data Science tutorial

# %% [markdown]
# # $\Omega$ Pandas
#
# > `pandas` is a Python package providing fast, flexible, and expressive data structures designed to make working with “relational” or “labeled” data both easy and intuitive. It aims to be the fundamental high-level building block for doing practical, real world data analysis in Python. Additionally, it has the broader goal of becoming the most powerful and flexible open source data analysis / manipulation tool available in any language. It is already well on its way toward this goal.
#
# > `pandas` is well suited for many different kinds of data:
#
# > * Tabular data with heterogeneously-typed columns, as in an SQL table or Excel spreadsheet
# * Ordered and unordered (not necessarily fixed-frequency) time series data.
# * Arbitrary matrix data (homogeneously typed or heterogeneous) with row and column labels
# * Any other form of observational / statistical data sets. The data actually need not be labeled at all to be placed into a pandas data structure
#
# For more tutorials, visit: https://pandas.pydata.org/pandas-docs/stable/tutorials.html

# %% [markdown]
# ### Imports
#
# Here we import Pandas and Matplotlib for data visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Read data
#
# The sinking of the RMS Titanic is one of the most infamous shipwrecks in history.  On April 15, 1912, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing 1502 out of 2224 passengers and crew. This sensational tragedy shocked the international community and led to better safety regulations for ships.
#
# One of the reasons that the shipwreck led to such loss of life was that there were not enough lifeboats for the passengers and crew. Although there was some element of luck involved in surviving the sinking, some groups of people were more likely to survive than others, such as women, children, and the upper-class.
#
# We load the data in using Pandas and create a Dataframe called `titanic`.

# %%
import pandas as pd
df = pd.read_csv("titanic.csv")

df.columns
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ### Help
#
# Jupyter provides a **magic** command to look at the documentation of a function by adding a question mark.

# %% [markdown]
# ### Get first n rows

# %%
# df.head(20)

# %%
df.shape
# Out:
# (1308, 14)

# %%
# get row number
df.shape[0]
# Out:
# 1308

# %%
# get column number
df.shape[1]
# Out:
# 14

# %%
# df.set_index(['name']).head()

# %% [markdown]
# ### Dataframe dimensions
#
# Get the number of rows and columns. `(rows, columns)`

# %% [markdown]
# ### Index
#
# The index is set to [0, 1, 2...nrows] by default if you don't specify it.

# %% [markdown]
# ### Columns

# %%
df.columns[0]
# Out:
# 'pclass'

# %% [markdown]
# ### Dataframe information
#
# Show some general information about your dataframe like the column names, the type, the number of non-missing values as well as the memory usage. Pandas Dataframes are loaded entirely into memory.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308 entries, 0 to 1307
# Data columns (total 14 columns):
# pclass       1308 non-null int64
# survived     1308 non-null int64
# name         1308 non-null object
# sex          1308 non-null object
# age          1045 non-null float64
# sibsp        1308 non-null int64
# parch        1308 non-null int64
# ticket       1308 non-null object
# fare         1308 non-null float64
# cabin        295 non-null object
# embarked     1306 non-null object
# boat         486 non-null object
# body         120 non-null float64
# home.dest    745 non-null object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.1+ KB

# %% [markdown]
# ### Summary statistics for numeric columns
#
# By default `describe` will include only numeric columns. By setting `include='all'` it also shows all types.

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1308.000000  1308.000000  1045.000000  1308.000000  1308.000000
# mean      2.294343     0.382263    29.851834     0.499235     0.385321
# std       0.837929     0.486126    14.389201     1.041965     0.865826
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  120.000000
# mean     33.295479  159.975000
# std      51.758668   97.672103
# min       0.000000    1.000000
# 25%       7.895800   71.500000
# 50%      14.454200  154.000000
# 75%      31.275000  255.250000
# max     512.329200  328.000000

# %% [markdown]
# # $\Omega$ Selecting Data

# %% [markdown]
# ### Select column

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df[['home.dest']].head()
# Out:
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ### Select multiple columns

# %%
df[['age','home.dest']].head()
# Out:
#        age                        home.dest
# 0  29.0000                     St Louis, MO
# 1   0.9167  Montreal, PQ / Chesterville, ON
# 2   2.0000  Montreal, PQ / Chesterville, ON
# 3  30.0000  Montreal, PQ / Chesterville, ON
# 4  25.0000  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ### Select rows and columns by name
#
# Use `loc` to slice your data. The first parameter is the names of the indices (this can be a range) and the second is a column or a list of columns.

# %%
df.loc[3]
# Out:
# pclass                                          1
# survived                                        0
# name         Allison, Mr. Hudson Joshua Creighton
# sex                                          male
# age                                            30
# sibsp                                           1
# parch                                           2
# ticket                                     113781
# fare                                       151.55
# cabin                                     C22 C26
# embarked                                        S
# boat                                          NaN
# body                                          135
# home.dest         Montreal, PQ / Chesterville, ON
# Name: 3, dtype: object

# %%
df.iloc[3,3]
# Out:
# 'male'

# %% [markdown]
# ### Select rows and columns by range of indices
#
# The difference with `iloc` is instead of using the **names** of the indices or columns, it uses the **integer positions**. For example instead selecting the 'age' column, we can select the column in position 4.

# %%
df.isna().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            0
# cabin        1013
# embarked        2
# boat          822
# body         1188
# home.dest     563
# dtype: int64

# %% [markdown]
# ### Select rows based on condition (filter)

# %%
df[df['age']<=30]
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12         1         1                      Aubart, Mme. Leontine Pauline
# 13         1         1                       Barber, Miss. Ellen "Nellie"
# 16         1         0                           Baxter, Mr. Quigg Edmond
# 22         1         1                              Behr, Mr. Karl Howell
# 24         1         1                                  Bird, Miss. Ellen
# 25         1         0                                Birnbaum, Mr. Jakob
# 26         1         1                            Bishop, Mr. Dickinson H
# 27         1         1            Bishop, Mrs. Dickinson H (Helen Walton)
# 29         1         1          Bjornstrom-Steffansson, Mr. Mauritz Hakan
# 32         1         1                            Bonnell, Miss. Caroline
# 36         1         1                        Bowerman, Miss. Elsie Edith
# 52         1         0                            Carrau, Mr. Francisco M
# 53         1         0                             Carrau, Mr. Jose Pedro
# 54         1         1                Carter, Master. William Thornton II
# 55         1         1                          Carter, Miss. Lucile Polk
# 64         1         1                      Chambers, Mr. Norman Campbell
# 67         1         1                               Cherry, Miss. Gladys
# 71         1         0                           Clark, Mr. Walter Miller
# 72         1         1      Clark, Mrs. Walter Miller (Virginia McDowell)
# 73         1         1                               Cleaver, Miss. Alice
# 87         1         1                        Daniel, Mr. Robert Williams
# 90         1         1               Davidson, Mrs. Thornton (Orian Hays)
# 92         1         1          Dick, Mrs. Albert Adrian (Vera Gillespie)
# 94         1         1                          Dodge, Master. Washington
# ...      ...       ...                                                ...
# 1239       3         1                    Thomas, Master. Assad Alexander
# 1243       3         1          Thomas, Mrs. Alexander (Thamine "Thelma")
# 1253       3         1                       Tornquist, Mr. William Henry
# 1255       3         1                     Touma, Master. Georges Youssef
# 1256       3         1                         Touma, Miss. Maria Youssef
# 1257       3         1            Touma, Mrs. Darwis (Hanne Youssef Razi)
# 1259       3         1                            Turja, Miss. Anna Sofia
# 1262       3         0                  van Billiard, Master. Walter John
# 1264       3         0                          Van Impe, Miss. Catharina
# 1266       3         0  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
#
# 1259  female  18.0      0      0                4138    9.8417          NaN
# 1272  female  18.0      2      0              345764   18.0000          NaN
# 1278  female  14.0      0      0              350406    7.8542          NaN
# 1299  female  15.0      1      0                2659   14.4542          NaN
# 1303  female  14.5      1      0                2665   14.4542          NaN
#
#      embarked boat   body                         home.dest
# 0           S    2    NaN                      St Louis, MO
# 4           S  NaN    NaN   Montreal, PQ / Chesterville, ON
# 11          C    4    NaN                      New York, NY
# 12          C    9    NaN                     Paris, France
# 13          S    6    NaN                               NaN
# 24          S    8    NaN                               NaN
# 27          C    7    NaN                      Dowagiac, MI
# 36          S    6    NaN  St Leonards-on-Sea, England Ohio
# 55          S    4    NaN                     Bryn Mawr, PA
# 72          C    4    NaN                   Los Angeles, CA
# 73          S   11    NaN                               NaN
# 90          S    3    NaN                      Montreal, PQ
# 92          S    3    NaN                       Calgary, AB
# 97          C    6    NaN                      Montreal, PQ
# 102         C    7    NaN         Mt Airy, Philadelphia, PA
# 111         S   10    NaN                      Winnipeg, MB
# 112         S   10    NaN                      Winnipeg, MB
# 113         S   10    NaN                      Winnipeg, MB
# 122         C    5    NaN               Zurich, Switzerland
# 130         C    7    NaN                      New York, NY
# 137         S    3    NaN                     Greenwich, CT
# 144         C    5    NaN                      Brooklyn, NY
# 153         C    7    NaN                      New York, NY
# 159         C    4    NaN                       Chicago, IL
# 187         S    9    NaN                     Paris, France
# 190         S   10    NaN                        Hudson, NY
# 193         S    2    NaN                      St Louis, MO
# 195         S    8    NaN                               NaN
# 198         S   10    NaN                      New York, NY
# 199         C    6    NaN             Belgium  Montreal, PQ
# ...       ...  ...    ...                               ...
# 1026        S   14    NaN                               NaN
# 1040        Q   15    NaN                               NaN
# 1047        C    C    NaN                               NaN
# 1050        C    C    NaN                               NaN
# 1057        C    C    NaN                               NaN
# 1058        S  NaN    NaN                               NaN
# 1060        S    D    NaN                               NaN
# 1061        S   13    NaN                               NaN
# 1067        S   13    NaN                               NaN
# 1079        S    C    NaN                               NaN
# 1090        S  NaN    NaN                               NaN
# 1091        S  NaN    NaN                               NaN
# 1100        S  NaN  206.0                               NaN
# 1113        S  NaN    NaN                               NaN
# 1126        S  NaN    NaN                               NaN
# 1130        S  NaN    NaN                               NaN
# 1147        S  NaN    NaN                               NaN
# 1182        S    C    NaN                               NaN
# 1188        S   13    NaN                               NaN
# 1205        S   16    NaN                               NaN
# 1223        S    C    NaN                               NaN
# 1226        S  NaN    NaN                               NaN
# 1230        S  NaN    NaN                               NaN
# 1243        C   14    NaN                               NaN
# 1257        C    C    NaN                               NaN
# 1259        S   15    NaN                               NaN
# 1272        S  NaN    NaN                               NaN
# 1278        S  NaN    NaN                               NaN
# 1299        C  NaN    NaN                               NaN
# 1303        C  NaN  328.0                               NaN
#
# [177 rows x 14 columns]

# %%
# man survived under 30 years old and over 50 years old
df[((df['sex'] == 'male')& (df['survived'] ==1) & (df['age']<30))| ((df['sex'] == 'male')&(df['survived'] ==1) & (df['age']>50))]
# Out:
#       pclass  survived                                             name   sex  \
# 1          1         1                   Allison, Master. Hudson Trevor  male
# 1231  16.0000      0      0    SOTON/OQ 392089    8.0500              NaN
# 1235  14.0000      0      0               7538    9.2250              NaN
# 1237  25.0000      0      0             350033    7.7958              NaN
# 1239   0.4167      0      1               2625    8.5167              NaN
# 1253  25.0000      0      0               LINE    0.0000              NaN
# 1255   7.0000      1      1               2650   15.2458              NaN
# 1276  22.0000      0      0               2658    7.2250              NaN
#
#      embarked   boat  body                           home.dest
# 1           S     11   NaN     Montreal, PQ / Chesterville, ON
# 14          S      B   NaN                       Hessle, Yorks
# 22          C      5   NaN                        New York, NY
# 26          C      7   NaN                        Dowagiac, MI
# 29          S      D   NaN  Stockholm, Sweden / Washington, DC
# 54          S      4   NaN                       Bryn Mawr, PA
# 64          S      5   NaN           New York, NY / Ithaca, NY
# 86          S    5 9   NaN                          Lima, Peru
# 87          S      3   NaN                    Philadelphia, PA
# 93          S     13   NaN                   San Francisco, CA
# 94          S      5   NaN                   San Francisco, CA
# 123         C      5   NaN                 Zurich, Switzerland
# 136         C      B   NaN                      Washington, DC
# 140         C      7   NaN                        New York, NY
# 143         C      5   NaN                        Brooklyn, NY
# 151         C      3   NaN                                 NaN
# 231         S      6   NaN                         Toronto, ON
# 249         C      4   NaN     Haverford, PA / Cooperstown, NY
# 264         C      3   NaN                  Basel, Switzerland
# 265         S      7   NaN                     New Britain, CT
# 271         S      7   NaN                     Minneapolis, MN
# 273         C      3   NaN                     Tuxedo Park, NY
# 280         C      1   NaN                          Newark, NJ
# 295         C      B   NaN                       Haverford, PA
# 317         C      A   NaN    Geneva, Switzerland / Radnor, PA
# 339         S     11   NaN  Guntur, India / Benton Harbour, MI
# 359         S     13   NaN   Bangkok, Thailand / Roseville, IL
# 360         S     13   NaN   Bangkok, Thailand / Roseville, IL
# 376         S      9   NaN             London / Fort Byron, NY
# 385         S     14   NaN     St Ives, Cornwall / Hancock, MI
# ...       ...    ...   ...                                 ...
# 783         S      D   NaN                  England Albion, NY
# 820         S    C D   NaN   Strood, Kent, England Detroit, MI
# 857         S     15   NaN                                 NaN
# 880         C     15   NaN                                 NaN
# 881         S      A   NaN                                 NaN
# 889         S     15   NaN                                 NaN
# 894         S     15   NaN                                 NaN
# 913         S     13   NaN                                 NaN
# 935         S      2   NaN                                 NaN
# 941         C     10   NaN                                 NaN
# 949         S     14   NaN                                 NaN
# 953         C      6   NaN                                 NaN
# 970         S     15   NaN                                 NaN
# 978         S     15   NaN                                 NaN
# 985         S     13   NaN                                 NaN
# 1017        S     15   NaN                                 NaN
# 1025        S     14   NaN                                 NaN
# 1049        C      C   NaN                                 NaN
# 1056        C      C   NaN                                 NaN
# 1082        S     13   NaN                                 NaN
# 1120        S     15   NaN                                 NaN
# 1190        S     11   NaN                                 NaN
# 1196        S     11   NaN                                 NaN
# 1231        S      B   NaN                                 NaN
# 1235        S     13   NaN                                 NaN
# 1237        S  13 15   NaN                                 NaN
# 1239        C     16   NaN                                 NaN
# 1253        S     15   NaN                                 NaN
# 1255        C      C   NaN                                 NaN
# 1049  20.0000      1      1               2653   15.7417              NaN
# 1056  12.0000      1      0               2651   11.2417              NaN
# 1082   9.0000      0      1            C 17368    3.1708              NaN
# 1120  25.0000      1      0             347083    7.7750              NaN
# 1190  25.0000      0      0             345768    9.5000              NaN
# 1196  29.0000      0      0             345779    9.5000              NaN
# 1231  16.0000      0      0    SOTON/OQ 392089    8.0500              NaN
# 1235  14.0000      0      0               7538    9.2250              NaN
# 1237  25.0000      0      0             350033    7.7958              NaN
# 1239   0.4167      0      1               2625    8.5167              NaN
# 1253  25.0000      0      0               LINE    0.0000              NaN
# 1255   7.0000      1      1               2650   15.2458              NaN
# 1276  22.0000      0      0               2658    7.2250              NaN
#
#      embarked   boat  body                           home.dest
# 1           S     11   NaN     Montreal, PQ / Chesterville, ON
# 14          S      B   NaN                       Hessle, Yorks
# 22          C      5   NaN                        New York, NY
# 26          C      7   NaN                        Dowagiac, MI
# 29          S      D   NaN  Stockholm, Sweden / Washington, DC
# 54          S      4   NaN                       Bryn Mawr, PA
# 64          S      5   NaN           New York, NY / Ithaca, NY
# 86          S    5 9   NaN                          Lima, Peru
# 87          S      3   NaN                    Philadelphia, PA
# 93          S     13   NaN                   San Francisco, CA
# 94          S      5   NaN                   San Francisco, CA
# 123         C      5   NaN                 Zurich, Switzerland
# 136         C      B   NaN                      Washington, DC
# 140         C      7   NaN                        New York, NY
# 143         C      5   NaN                        Brooklyn, NY
# 151         C      3   NaN                                 NaN
# 231         S      6   NaN                         Toronto, ON
# 249         C      4   NaN     Haverford, PA / Cooperstown, NY
# 264         C      3   NaN                  Basel, Switzerland
# 265         S      7   NaN                     New Britain, CT
# 271         S      7   NaN                     Minneapolis, MN
# 273         C      3   NaN                     Tuxedo Park, NY
# 280         C      1   NaN                          Newark, NJ
# 295         C      B   NaN                       Haverford, PA
# 317         C      A   NaN    Geneva, Switzerland / Radnor, PA
# 339         S     11   NaN  Guntur, India / Benton Harbour, MI
# 359         S     13   NaN   Bangkok, Thailand / Roseville, IL
# 360         S     13   NaN   Bangkok, Thailand / Roseville, IL
# 376         S      9   NaN             London / Fort Byron, NY
# 385         S     14   NaN     St Ives, Cornwall / Hancock, MI
# ...       ...    ...   ...                                 ...
# 783         S      D   NaN                  England Albion, NY
# 820         S    C D   NaN   Strood, Kent, England Detroit, MI
# 857         S     15   NaN                                 NaN
# 880         C     15   NaN                                 NaN
# 881         S      A   NaN                                 NaN
# 889         S     15   NaN                                 NaN
# 894         S     15   NaN                                 NaN
# 913         S     13   NaN                                 NaN
# 935         S      2   NaN                                 NaN
# 941         C     10   NaN                                 NaN
# 949         S     14   NaN                                 NaN
# 953         C      6   NaN                                 NaN
# 970         S     15   NaN                                 NaN
# 978         S     15   NaN                                 NaN
# 985         S     13   NaN                                 NaN
# 1017        S     15   NaN                                 NaN
# 1025        S     14   NaN                                 NaN
# 1049        C      C   NaN                                 NaN
# 1056        C      C   NaN                                 NaN
# 1082        S     13   NaN                                 NaN
# 1120        S     15   NaN                                 NaN
# 1190        S     11   NaN                                 NaN
# 1196        S     11   NaN                                 NaN
# 1231        S      B   NaN                                 NaN
# 1235        S     13   NaN                                 NaN
# 1237        S  13 15   NaN                                 NaN
# 1239        C     16   NaN                                 NaN
# 1253        S     15   NaN                                 NaN
# 1255        C      C   NaN                                 NaN
# 1276        C  13 15   NaN                                 NaN
#
# [88 rows x 14 columns]

# %% [markdown]
# ## $\Delta$ Exercise 1 - Toronto Crime Dataset
#
# http://data.torontopolice.on.ca/datasets/mci-2014-to-2017
#
# **Questions:**
# 1. Read the crime data `crime.csv` and set it to the variable `crime`
# 2. Show the last 10 rows (hint: use `tail`)
# 3. Show the summary statistics
# 4. Select columns "Lat" and "Long" and rows 100 to 200

# %%
########################
# Your Code Below
########################
crime = pd.read_csv("crime.csv")
crime.tail(10)
# Out:
#                   occurrencedate              reporteddate        Lat  \
# 131063  2014-09-13T04:00:00.000Z  2014-09-15T04:00:00.000Z  43.694473
# 131064  2014-09-15T04:00:00.000Z  2014-09-16T04:00:00.000Z  43.695751
# 131065  2014-09-15T04:00:00.000Z  2014-09-16T04:00:00.000Z  43.748486
# 131066  2014-09-15T04:00:00.000Z  2014-09-16T04:00:00.000Z  43.709904
# 131067  2014-09-18T04:00:00.000Z  2014-09-18T04:00:00.000Z  43.688309
# 131068  2014-09-18T04:00:00.000Z  2014-09-18T04:00:00.000Z  43.743305
# 131069  2014-09-20T04:00:00.000Z  2014-09-21T04:00:00.000Z  43.693031
# 131070  2014-09-22T04:00:00.000Z  2014-09-22T04:00:00.000Z  43.788761
# 131071  2014-09-21T04:00:00.000Z  2014-09-22T04:00:00.000Z  43.726807
# 131072  2014-09-22T04:00:00.000Z  2014-09-22T04:00:00.000Z  43.652630
#
#              Long                      Neighbourhood premisetype         MCI
# 131063 -79.548469  Kingsview Village-The Westway (6)     Outside  Auto Theft
# 131064 -79.510284                       Weston (113)     Outside  Auto Theft
# 131065 -79.550110                    Humbermede (22)     Outside  Auto Theft
# 131066 -79.515373          Pelmo Park-Humberlea (23)       House  Auto Theft
# 131067 -79.493141                 Mount Dennis (115)     Outside  Auto Theft
# 131068 -79.406494          St.Andrew-Windfields (40)     Outside  Auto Theft
# 131069 -79.564003  Kingsview Village-The Westway (6)  Commercial  Auto Theft
# 131070 -79.162148               Highland Creek (134)       House  Auto Theft
# 131071 -79.459641            Yorkdale-Glen Park (31)     Outside  Auto Theft
# 131072 -79.366463                     Moss Park (73)     Outside  Auto Theft

# %%
crime.describe(include='all')
# Out:
#                   occurrencedate              reporteddate            Lat  \
# count                     131073                    131073  131073.000000
# unique                      1800                      1461            NaN
# top     2014-01-01T05:00:00.000Z  2015-11-16T05:00:00.000Z            NaN
# freq                         197                       144            NaN
# mean                         NaN                       NaN      43.708025
# std                          NaN                       NaN       0.052587
# min                          NaN                       NaN      43.587093
# 25%                          NaN                       NaN      43.661774
# 50%                          NaN                       NaN      43.702255
# 75%                          NaN                       NaN      43.752491
# max                          NaN                       NaN      43.847954
#
#                  Long               Neighbourhood premisetype      MCI
# count   131073.000000                      131073      131073   131073
# unique            NaN                         140           5        5
# top               NaN  Church-Yonge Corridor (75)     Outside  Assault
# freq              NaN                        4699       34996    71440
# mean       -79.394158                         NaN         NaN      NaN
# std          0.105263                         NaN         NaN      NaN
# min        -79.635239                         NaN         NaN      NaN
# 25%        -79.473244                         NaN         NaN      NaN
# 50%        -79.393280                         NaN         NaN      NaN
# 75%        -79.315636                         NaN         NaN      NaN
# max        -79.123100                         NaN         NaN      NaN

# %%
crime.columns
# Out:
# Index(['occurrencedate', 'reporteddate', 'Lat', 'Long', 'Neighbourhood',
#        'premisetype', 'MCI'],
#       dtype='object')

# %%
crime[['Lat', 'Long']][100: 201]
# Out:
#            Lat       Long
# 100  43.652947 -79.398048
# 101  43.670200 -79.360153
# 102  43.671917 -79.379067
# 103  43.782120 -79.293465
# 104  43.647739 -79.361046
# 105  43.652947 -79.398048
# 106  43.640205 -79.394432
# 107  43.712444 -79.272407
# 108  43.696152 -79.291565
# 109  43.698837 -79.515877
# 110  43.625210 -79.528549
# 111  43.817764 -79.307747
# 112  43.677147 -79.354057
# 113  43.667465 -79.404190
# 114  43.645374 -79.392059
# 115  43.645763 -79.393639
# 116  43.690609 -79.411522
# 117  43.787392 -79.269295
# 118  43.831047 -79.275192
# 119  43.648712 -79.400940
# 120  43.758625 -79.492828
# 121  43.776482 -79.172516
# 122  43.693035 -79.342453
# 123  43.690609 -79.411522
# 124  43.702721 -79.417381
# 125  43.622021 -79.522026
# 126  43.716557 -79.337318
# 127  43.716557 -79.337318
# 128  43.775837 -79.343719
# 129  43.821056 -79.206200
# ..         ...        ...
# 171  43.643929 -79.402702
# 172  43.643929 -79.402702
# 173  43.635597 -79.426086
# 174  43.767654 -79.189613
# 175  43.787392 -79.269295
# 176  43.660564 -79.337273
# 177  43.730846 -79.273888
# 178  43.730846 -79.273888
# 179  43.693287 -79.454147
# 180  43.694424 -79.308235
# 181  43.694424 -79.308235
# 182  43.756603 -79.497658
# 183  43.659225 -79.443047
# 184  43.735317 -79.578972
# 185  43.666729 -79.446465
# 186  43.782597 -79.224319
# 187  43.689041 -79.297897
# 188  43.689041 -79.297897
# 189  43.657040 -79.381226
# 190  43.657040 -79.381226
# 191  43.657040 -79.381226
# 192  43.669807 -79.479950
# 193  43.789280 -79.194359
# 194  43.761299 -79.324997
# 195  43.647160 -79.369186
# 196  43.758137 -79.509125
# 197  43.779636 -79.345734
# 198  43.644779 -79.398506
# 199  43.612106 -79.489891
# 200  43.695316 -79.450119
#
# [101 rows x 2 columns]

# %% [markdown]
# # $\Omega$ Transforming Data

# %% [markdown]
# ### Calculate ticket price in today's dollar
# According to the Bureau of Labor Statistics consumer price index, prices in 2018 are 2,669.00% higher than prices in 1909. The dollar experienced an average inflation rate of 3.09% per year.

# %%
# df.fare*26.69

# %% [markdown]
# ### Add new column

# %%
df['present_fare'] = df.fare*(26.69 + 0.039)
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest  present_fare
# 0                     St Louis, MO   5648.840038
# 1  Montreal, PQ / Chesterville, ON   4050.779950
# 2  Montreal, PQ / Chesterville, ON   4050.779950
# 3  Montreal, PQ / Chesterville, ON   4050.779950
# 4  Montreal, PQ / Chesterville, ON   4050.779950

# %% [markdown]
# ### Count missing values

# %%
# df.isnull().sum()
df.isna().sum()
# Out:
# pclass             0
# survived           0
# name               0
# sex                0
# age              263
# sibsp              0
# parch              0
# ticket             0
# fare               0
# cabin           1013
# embarked           2
# boat             822
# body            1188
# home.dest        563
# present_fare       0
# dtype: int64

# %% [markdown]
# ### Calculate mean

# %%
df.mean()
# Out:
# pclass            2.294343
# survived          0.382263
# age              29.851834
# sibsp             0.499235
# parch             0.385321
# fare             33.295479
# body            159.975000
# present_fare    889.954866
# dtype: float64

# %% [markdown]
# ### Fill missing values

# %%
# fill missing values in one column with it's mean
ageMean = df.age.mean()b

# ageMean
df.age = df.fillna(ageMean)
# df.tail()
df.isna().sum()
# df['age'].mean()
# Out:
# pclass             0
# survived           0
# name               0
# sex                0
# age                0
# sibsp              0
# parch              0
# ticket             0
# fare               0
# cabin           1013
# embarked           2
# boat             822
# body            1188
# home.dest        563
# present_fare       0
# dtype: int64

# %%
df.mean()
# Out:
# pclass            2.294343
# survived          0.382263
# age               2.294343
# sibsp             0.499235
# parch             0.385321
# fare             33.295479
# body              2.294343
# present_fare    889.954866
# dtype: float64

# %%
# how to fill missing values in multiple columns?
# df.mean()
pclassmean = df.pclass.mean()
# pclassmean

agemean = df.age.mean()
faremean = df.fare.mean()
df.fillna({'pclass':pclassmean,'age':agemean,'fare':faremean }, inplace=True)
df
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12         1         1                      Aubart, Mme. Leontine Pauline
# 13         1         1                       Barber, Miss. Ellen "Nellie"
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
# 15         1         0                                Baumann, Mr. John D
# 16         1         0                           Baxter, Mr. Quigg Edmond
# 17         1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18         1         1                              Bazzani, Miss. Albina
# 19         1         0                               Beattie, Mr. Thomson
# 20         1         1                      Beckwith, Mr. Richard Leonard
# 21         1         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 22         1         1                              Behr, Mr. Karl Howell
# 23         1         1                              Bidois, Miss. Rosalie
# 24         1         1                                  Bird, Miss. Ellen
# 25         1         0                                Birnbaum, Mr. Jakob
# 26         1         1                            Bishop, Mr. Dickinson H
# 27         1         1            Bishop, Mrs. Dickinson H (Helen Walton)
# 28         1         1                             Bissette, Miss. Amelia
# 29         1         1          Bjornstrom-Steffansson, Mr. Mauritz Hakan
# ...      ...       ...                                                ...
# 1278       3         0               Vestrom, Miss. Hulda Amanda Adolfina
# 1279       3         0                                    Vovk, Mr. Janko
# 1280       3         0                               Waelens, Mr. Achille
# 1281       3         0                                Ware, Mr. Frederick
# 1282       3         0                        Warren, Mr. Charles William
# 1283       3         0                                  Webber, Mr. James
# 1284       3         0                                Wenzel, Mr. Linhart
# 1285       3         1    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1286       3         0                   Widegren, Mr. Carl/Charles Peter
# 1287       3         0                          Wiklund, Mr. Jakob Alfred
# 1288       3         0                            Wiklund, Mr. Karl Johan
# 1289       3         1                   Wilkes, Mrs. James (Ellen Needs)
# 1290       3         0                   Willer, Mr. Aaron ("Abi Weller")
# 1291       3         0                                 Willey, Mr. Edward
# 1292       3         0                  Williams, Mr. Howard Hugh "Harry"
# 1293       3         0                               Williams, Mr. Leslie
# 1294       3         0                                Windelov, Mr. Einar
# 1295       3         0                                   Wirz, Mr. Albert
# 1296       3         0                             Wiseman, Mr. Phillippe
# 1297       3         0                          Wittevrongel, Mr. Camille
# 1298       3         0                                Yasbeck, Mr. Antoni
# 1299       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
# 1300       3         0                               Youseff, Mr. Gerious
# 1301       3         0                                  Yousif, Mr. Wazli
# 1302       3         0                              Yousseff, Mr. Gerious
# 1303       3         0                               Zabour, Miss. Hileni
# 1304       3         0                              Zabour, Miss. Thamine
# 1305       3         0                          Zakarian, Mr. Mapriededer
# 1306       3         0                                Zakarian, Mr. Ortin
# 1307       3         0                                 Zimmerman, Mr. Leo
#
#          sex  age  sibsp  par
# 0       2    1                        St Louis, MO   5648.840038
# 1      11    1     Montreal, PQ / Chesterville, ON   4050.779950
# 2     NaN    1     Montreal, PQ / Chesterville, ON   4050.779950
# 3     NaN    1     Montreal, PQ / Chesterville, ON   4050.779950
# 4     NaN    1     Montreal, PQ / Chesterville, ON   4050.779950
# 5       3    1                        New York, NY    709.654950
# 6      10    1                          Hudson, NY   2083.747401
# 7     NaN    1                         Belfast, NI      0.000000
# 8       D    1                 Bayside, Queens, NY   1375.987537
# 9     NaN    1                 Montevideo, Uruguay   1323.197762
# 10    NaN    1                        New York, NY   6081.515725
# 11      4    1                        New York, NY   6081.515725
# 12      9    1                       Paris, France   1852.319700
# 13      6    1                                 NaN   2107.581650
# 14      B    1                       Hessle, Yorks    801.870000
# 15    NaN    1                        New York, NY    692.949325
# 16    NaN    1                        Montreal, PQ   6615.983463
# 17      6    1                        Montreal, PQ   6615.983463
# 18      8    1                                 NaN   2039.200849
# 19      A    1                        Winnipeg, MN   2011.135399
# 20      5    1                        New York, NY   1404.721212
# 21      5    1                        New York, NY   1404.721212
# 22      5    1                        New York, NY    801.870000
# 23      4    1                                 NaN   6081.515725
# 24      8    1                                 NaN   5927.936237
# 25    NaN    1                   San Francisco, CA    694.954000
# 26      7    1                        Dowagiac, MI   2434.455937
# 27      7    1                        Dowagiac, MI   2434.455937
# 28      8    1                                 NaN   3625.342476
# 29      D    1  Stockholm, Sweden / Washington, DC    709.654950
# ...   ...  ...                                 ...           ...
# 1278  NaN    3                                 NaN    209.934912
# 1279  NaN    3                                 NaN    211.046838
# 1280  NaN    3      Antwerp, Belgium / Stanton, OH    240.561000
# 1281  NaN    3                                 NaN    215.168450
# 1282  NaN    3                                 NaN    201.803950
# 1283  NaN    3                                 NaN    215.168450
# 1284  NaN    3                                 NaN    253.925500
# 1285    C    3                                 NaN    193.229287
# 1286  NaN    3                                 NaN    207.149750
# 1287  NaN    3                                 NaN    173.626238
# 1288  NaN    3                                 NaN    173.626238
# 1289  NaN    3                                 NaN    187.103000
# 1290  NaN    3                                 NaN    232.876413
# 1291  NaN    3                                 NaN    201.803950
# 1292  NaN    3                                 NaN    215.168450
# 1293  NaN    3                                 NaN    430.336900
# 1294  NaN    3                                 NaN    193.785250
# 1295  NaN    3                                 NaN    231.539963
# 1296  NaN    3                                 NaN    193.785250
# 1297  NaN    3                                 NaN    253.925500
# 1298    C    3                                 NaN    386.346312
# 1299  NaN    3                                 NaN    386.346312
# 1300  NaN    3                                 NaN    193.117025
# 1301  NaN    3                                 NaN    193.117025
# 1302  NaN    3                                 NaN    386.455901
# 1303  NaN    3                                 NaN    386.346312
# 1304  NaN    3                                 NaN    386.346312
# 1305  NaN    3                                 NaN    193.117025
# 1306  NaN    3                                 NaN    193.117025
# 1307  NaN    3                                 NaN    210.490875
#
# [1308 rows x 15 columns]

# %%
df.body.mean()
# Out:
# 159.975

# %% [markdown]
# ### Count categorical data

# %%
df.dtypes
# Out:
# pclass            int64
# survived          int64
# name             object
# sex              object
# age              object
# sibsp             int64
# parch             int64
# ticket           object
# fare            float64
# cabin            object
# embarked         object
# boat             object
# body            float64
# home.dest        object
# present_fare    float64
# dtype: object

# %%
df.survived.value_counts()
# Out:
# 0    808
# 1    500
# Name: survived, dtype: int64

# %% [markdown]
# ### Groupby & aggregate

# %%
df.groupby('sex').sibsp.sum()
# Out:
# sex
# female    304
# male      349
# Name: sibsp, dtype: int64

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest',
#        'present_fare'],
#       dtype='object')

# %% [markdown]
# ### Save new dataframe as csv

# %% [markdown]
# ## $\Delta$ Exercise 2 - Crime Dataset
#
# Some helpful functions:
# - `pd.to_datetime`
# - `.dt.year`
# - `.dt.month`
# - `.dt.dayofweek`
# - `.dt.hour`
#
# **Questions:**
# 1. Create a new column called `datetime` by converting `occurrencedate` to a datetime object
# 2. Create a new column called `year`
# 3. Create a new column called `month`
# 4. Create a new column called `dayofweek`
# 5. Create a new column called `hour`
# 6. Print the type of every column
# 7. Print new summary statistics

# %%
########################
# Your Code Below
########################

# crime.columns
crime['datetime'] = pd.to_datetime(crime['occurrencedate'], errors='ignore')
crime.head()
# Out:
#              occurrencedate              reporteddate        Lat       Long  \
# 0  2014-08-25T04:00:00.000Z  2014-08-25T04:00:00.000Z  43.768829 -79.520401
# 1  2014-08-25T04:00:00.000Z  2014-09-08T04:00:00.000Z  43.642574 -79.580856
# 2  2014-08-25T04:00:00.000Z  2014-08-29T04:00:00.000Z  43.762909 -79.260445
# 3  2014-08-25T04:00:00.000Z  2014-08-26T04:00:00.000Z  43.663208 -79.367546
# 4  2014-08-25T04:00:00.000Z  2014-08-26T04:00:00.000Z  43.776440 -79.231758
#
#                           Neighbourhood premisetype              MCI  \
# 0                      Black Creek (24)     Outside          Assault
# 1   Eringate-Centennial-West Deane (11)       House  Break and Enter
# 2                         Bendale (127)       House          Assault
# 3  Cabbagetown-South St.James Town (71)  Commercial  Break and Enter
# 4                          Woburn (137)       Other  Break and Enter
#
#                    datetime
# 0 2014-08-25 04:00:00+00:00
# 1 2014-08-25 04:00:00+00:00
# 2 2014-08-25 04:00:00+00:00
# 3 2014-08-25 04:00:00+00:00
# 4 2014-08-25 04:00:00+00:00

# %%
# import datetime as dt
crime['year'] = crime['datetime'].dt.year
crime['month'] = crime['datetime'].dt.month
crime['dayoftheweek'] = crime['datetime'].dt.dayofweek
crime['hour'] = crime['datetime'].dt.hour
# crime.info()
crime.describe(include='all')
# Out:
#                   occurrencedate              reporteddate            Lat  \
# count                     131073                    131073  131073.000000
# unique                      1800                      1461            NaN
# top     2014-01-01T05:00:00.000Z  2015-11-16T05:00:00.000Z            NaN
# freq                         197                       144            NaN
# first                        NaN                       NaN            NaN
# last                         NaN                       NaN            NaN
# mean                         NaN                       NaN      43.708025
# std                          NaN                       NaN       0.052587
# min                          NaN                       NaN      43.587093
# 25%                          NaN                       NaN      43.661774
# 50%                          NaN                       NaN      43.702255
# 75%                          NaN                       NaN      43.752491
# max                          NaN                       NaN      43.847954
#
#                  Long               Neighbourhood premisetype      MCI  \
# count   131073.000000                      131073      131073   131073
# unique            NaN                         140           5        5
# top               NaN  Church-Yonge Corridor (75)     Outside  Assault
# freq              NaN                        4699       34996    71440
# first             NaN                         NaN         NaN      NaN
# last              NaN                         NaN         NaN      NaN
# mean       -79.394158                         NaN         NaN      NaN
# std          0.105263                         NaN         NaN      NaN
# min        -79.635239                         NaN         NaN      NaN
# 25%        -79.473244                         NaN         NaN      NaN
# 50%        -79.393280                         NaN         NaN      NaN
# 75%        -79.315636                         NaN         NaN      NaN
# max        -79.123100                         NaN         NaN      NaN
#
#                          datetime           year          month  \
# count                      131073  131073.000000  131073.000000
# unique                       1800            NaN            NaN
# top     2014-01-01 05:00:00+00:00            NaN            NaN
# freq                          197            NaN            NaN
# first   1966-06-09 04:00:00+00:00            NaN            NaN
# last    2017-12-31 05:00:00+00:00            NaN            NaN
# mean                          NaN    2015.492184       6.654139
# std                           NaN       1.282269       3.392123
# min                           NaN    1966.000000       1.000000
# 25%                           NaN    2015.000000       4.000000
# 50%                           NaN    2016.000000       7.000000
# 75%                           NaN    2017.000000      10.000000
# max                           NaN    2017.000000      12.000000
#
#          dayoftheweek           hour
# count   131073.000000  131073.000000
# unique            NaN            NaN
# top               NaN            NaN
# freq              NaN            NaN
# first             NaN            NaN
# last              NaN            NaN
# mean         3.074912       4.332334
# std          1.996135       0.471052
# min          0.000000       4.000000
# 25%          1.000000       4.000000
# 50%          3.000000       4.000000
# 75%          5.000000       5.000000
# max          6.000000       5.000000

# %%
crime[crime.year == 2014].shape[0]
# Out:
# 31578

# %% [markdown]
# # $\Omega$ Data Visualization
# https://pandas.pydata.org/pandas-docs/stable/visualization.html

# %% [markdown]
# ### Bar plot

# %%
import matplotlib.pyplot as plt
df['sex'].value_counts().plot(kind = "bar")

# %% [markdown]
# ### Pie plot

# %%
df['sex'].value_counts().plot(kind="pie")

# %% [markdown]
# ### Set figure size

# %%
type(df.age.value_counts())
# Out:
# pandas.core.series.Series

# %%
df['age'].hist()

# %%
df.age.plot(kind="hist")

# %% [markdown]
# ### Set global style

# %% [markdown]
# ### Histogram

# %% [markdown]
# ### Set histogram bin size

# %%
hist = df.hist(bins=3)

# %% [markdown]
# ### Boxplot

# %%
df['age'].value_counts().plot(kind='box')

# %% [markdown]
# ### Scatter plot

# %%
df.plot.scatter(x='age', y='fare', colormap='viridis')
# df.columns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-49ca54996d43> in <module>
# ----> 1 df.plot.scatter(x='age', y='fare', colormap='viridis')
#       2 # df.columns
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in scatter(self, x, y, s, c, **kwds)
#    3514             ...                       colormap='viridis')
#    3515         """
# -> 3516         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    3517
#    3518     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
#    2941                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2942                           sort_columns=sort_columns, **kwds)
#    2943     __call__.__doc__ = plot_frame.__doc__
#    2944
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1971                  yerr=yerr, xerr=xerr,
#    1972                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1973                  **kwds)
#    1974
#    1975
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1738         if isinstance(data, ABCDataFrame):
#    1739             plot_obj = klass(data, x=x, y=y, subplots=subplots, ax=ax,
# -> 1740                              kind=kind, **kwds)
#    1741         else:
#    1742             raise ValueError("plot kind %r can only be used for data frames"
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __init__(self, data, x, y, s, c, **kwargs)
#     858             # the handling of this argument later
#     859             s = 20
# --> 860         super(ScatterPlot, self).__init__(data, x, y, s=s, **kwargs)
#     861         if is_integer(c) and not self.data.columns.holds_integer():
#     862             c = self.data.columns[c]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __init__(self, data, x, y, **kwargs)
#     802             y = self.data.columns[y]
#     803         if len(self.data[x]._get_numeric_data()) == 0:
# --> 804             raise ValueError(self._kind + ' requires x column to be numeric')
#     805         if len(self.data[y]._get_numeric_data()) == 0:
#     806             raise ValueError(self._kind + ' requires y column to be numeric')
#
# ValueError: scatter requires x column to be numeric

# %% [markdown]
# ### Transform then plot

# %% [markdown]
# ## $\Delta$ Exercise 3 - Crime Dataset
#
# **Questions:**
# 1. Create a bar plot of `MCI`
# 2. Create a line and bar plot of `year`
# 3. Filter the dataframe for only years greater than or equal to 2014
# 4. Create a histogram of `Lat`
# 5. Create a histogram of `Long`
# 6. Get the 10 Neighbourhoods with the most crime
#
# **Bonus:**
# - Explore the dataset and see if you can come up with your own interesting analysis or plot

# %%
########################
# Your Code Below
########################
# Create a bar plot of MCI
# crime.columns
crime.MCI.value_counts().plot(kind = "bar")

# %%
# Create a line and bar plot of year
# crime.year.value_counts().plot(kind="bar")
crime.year.value_counts().plot(linestyle='-', marker='o')

# %%
# Filter the dataframe for only years greater than or equal to 2014
crime[crime['year']>2014]

# %%
# Create a histogram of Lat
crime['Lat'].value_counts().plot(kind="hist")

# %%
# Create a histogram of Lat
crime['Long'].value_counts().plot(kind="hist")

# %%
# Get the 10 Neighbourhoods with the most crime
crime.columns
crime['Neighbourhood'].value_counts().head(10).plot(kind='bar')

# %% [markdown]
# # $\Omega$ Machine Learning
#
# > Scikit-learn (formerly scikits.learn) is a free software machine learning library for the Python programming language. It features various classification, regression and clustering algorithms including support vector machines, random forests, gradient boosting, k-means and DBSCAN, and is designed to interoperate with the Python numerical and scientific libraries NumPy and SciPy.
#
# http://scikit-learn.org/stable/user_guide.html

# %% [markdown]
# - `pip install scikit-plot`
# - `pip install mlxtend`

# %%
from sklearn.datasets import make_blobs
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from mlxtend.plotting import category_scatter
from mlxtend.plotting import plot_decision_regions
from sklearn.linear_model import LogisticRegression


import scikitplot as skplt
# make_blobs
# RandomForestClassifier
LogisticRegression()

# %%
X, y = make_blobs(centers=[[1, 1], [2, 2]], random_state=1)

df = pd.DataFrame(X, columns=['feature1', 'feature2']).assign(label=y)

df.head()

# %%
category_scatter(x='feature1', y='feature2', label_col='label', data=df);

# %%
d_tree = DecisionTreeClassifier(max_depth=10)
d_tree.fit(X, y)

plot_decision_regions(X, y, clf=d_tree);

# %% [markdown]
# ### Titanic

# %%
titanic.head()

# %% [markdown]
# ### Selecting features

# %% [markdown]
# ### One hot encoding

# %% [markdown]
# ### Make feature dataset

# %% [markdown]
# ### Make label

# %% [markdown]
# ### Make validation dataset

# %% [markdown]
# ### Build/train model

# %% [markdown]
# ### Model accuracy

# %% [markdown]
# ### Model prediction

# %% [markdown]
# ### Model evaluation

# %% [markdown]
# ## $\Delta$ Exercise 4 - Crime Dataset
#
# **Questions:**
# 1. Create a list of features: Lat, Long, year, month, dayofweek, hour, premisetype
# 2. One hot encode the premisetype
# 3. Create the feature set called `X`
# 4. Create the target label `y` by encoding the `MCI` column
# 5. Train and evaluate a model

# %% [markdown]
# ### Random Forest

# %% [markdown]
# # $\Omega$ Model Deployment

# %%
model.predict([[43.669895, -79.390205, 2018, 9, 4, 9, 0, 0, 0, 0, 1]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-9af7bb405174> in <module>
# ----> 1 model.predict([[43.669895, -79.390205, 2018, 9, 4, 9, 0, 0, 0, 0, 1]])
#
# NameError: name 'model' is not defined
